# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# 1. 데이터 로드 및 전처리

df = pd.read_csv('../DSA_features.csv')
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
# activity 열에 포함된 고유한 값(활동 유형) 확인
unique_activities = df['activity'].unique()
print(unique_activities)
# Out:
# ['sitting' 'standing' 'lyingBack' 'lyingRigh' 'ascendingStairs'
#  'decendingStairs' 'standingInElevatorStill' 'movingInElevator'
#  'walkingLot' 'walkingTreadmillFlat' 'walkingTreadmillIncline'
#  'runningTreadmill' 'stepper' 'crossTrainer' 'cyclingHorizontal'
#  'cyclingVertical' 'rowing' 'jumping' 'basketBall']

# %%
# lyingRight, lyingBack (정상), jumping (비정상) 데이터 필터링
df = df[df['activity'].isin(['lyingRight', 'lyingBack', 'jumping'])]

# 정상: 0 (lying), 비정상: 1 (jumping) 라벨 설정
df['label'] = df['activity'].apply(lambda x: 0 if x in ['lyingRight', 'lyingBack'] else 1)

# 라벨과 사람 ID, 활동명을 제외한 피처만 선택
features = df.drop(['activity', 'label', 'people'], axis=1)
labels = df['label'].values
# Out:
# C:\Users\tyra\AppData\Local\Temp\ipykernel_28268\1770365912.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['activity'].apply(lambda x: 0 if x in ['lyingRight', 'lyingBack'] else 1)

# %%
# 2. 데이터 정규화 및 학습/테스트 분할

# %%
# 데이터 정규화
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# 정상 데이터만으로 학습 데이터 구성
train_data = features_scaled[labels == 0]

# 테스트 데이터 전체
test_data = features_scaled
test_labels = labels

# %%
# 3. Autoencoder 모델 정의 및 학습

# %%
# Autoencoder 모델 정의
input_dim = train_data.shape[1]
encoding_dim = 16  # 은닉층의 뉴런 수 설정

input_layer = Input(shape=(input_dim,))
encoder = Dense(encoding_dim, activation="relu")(input_layer)
decoder = Dense(input_dim, activation="linear")(encoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(train_data, train_data, epochs=50, batch_size=32, shuffle=True, validation_split=0.1)
# Out:
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7007 - val_loss: 0.4603
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5809 - val_loss: 0.3457
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4472 - val_loss: 0.2766
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4089 - val_loss: 0.2566
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3554 - val_loss: 0.2473
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2799 - val_loss: 0.2439
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3433 - val_loss: 0.2377
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2936 - val_loss: 0.2254
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2851 - val_loss: 0.2137
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2497 - val_loss: 0.2044
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2637 - val_loss: 0.1981
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2060 - val_loss: 0.1905
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2226 - val_loss: 0.1854
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2274 - val_loss: 0.1810
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2310 - val_loss: 0.1767
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2282 - val_loss: 0.1751
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1677 - val_loss: 0.1722
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1971 - val_loss: 0.1691
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1823 - val_loss: 0.1659
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1654 - val_loss: 0.1651
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1541 - val_loss: 0.1629
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1429 - val_loss: 0.1629
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1779 - val_loss: 0.1599
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1488 - val_loss: 0.1589
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1401 - val_loss: 0.1590
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1502 - val_loss: 0.1580
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1373 - val_loss: 0.1581
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1290 - val_loss: 0.1541
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1305 - val_loss: 0.1553
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1258 - val_loss: 0.1522
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1186 - val_loss: 0.1518
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1155 - val_loss: 0.1495
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1135 - val_loss: 0.1480
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1087 - val_loss: 0.1482
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1138 - val_loss: 0.1472
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1156 - val_loss: 0.1451
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1011 - val_loss: 0.1442
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1042 - val_loss: 0.1443
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0997 - val_loss: 0.1421
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1068 - val_loss: 0.1417
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0972 - val_loss: 0.1408
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0910 - val_loss: 0.1402
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0876 - val_loss: 0.1397
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0883 - val_loss: 0.1385
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0854 - val_loss: 0.1390
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0959 - val_loss: 0.1378
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0934 - val_loss: 0.1366
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0904 - val_loss: 0.1364
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0956 - val_loss: 0.1360
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0834 - val_loss: 0.1362

# %%
# 4. 테스트 데이터에서 재구성 오류 계산

# %%
# Autoencoder를 통해 재구성 오류 계산
test_predictions = autoencoder.predict(test_data)
mse = np.mean(np.power(test_data - test_predictions, 2), axis=1)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step

# %%
# 5. 임계값 설정 및 비정상 데이터 분류

# %%
# 임계값 설정 (예: 정상 데이터의 95번째 백분위수)
threshold = np.percentile(mse[labels == 0], 95)

# 예측: 임계값보다 큰 오류는 비정상(1), 작은 오류는 정상(0)으로 분류
predictions = [1 if error > threshold else 0 for error in mse]

# %%
#6. 정확도 평가

# %%
# 정확도 계산
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(test_labels, predictions)
print("Autoencoder Model Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Autoencoder Model Accuracy: 97.50%

# %%
# 정확도가 97.50%로 매우 긍정적이다.
